# %% [markdown]
# <a href="https://colab.research.google.com/github/d-arroyo1974/OCY1105-Ciberseguridad-Defensiva/blob/main/Act_S5_Preservaci%C3%B3n_de_Evidencia_Digital_y_Cadena_de_Custodia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 📝 FORMULARIO DE RESPUESTAS: Semana 5 - Forense y Cadena de Custodia
#@markdown ---
#@markdown **1. Diferencia entre Evidencia Volátil vs No Volátil:**
Respuesta_Volatil_S5 = "" #@param {type:"string"}

#@markdown **2. Algoritmo de Hashing utilizado (SHA-256 / MD5) y su propósito:**
Respuesta_Hash_S5 = "" #@param {type:"string"}

#@markdown **3. Procedimiento clave para asegurar la Cadena de Custodia:**
Respuesta_Custodia_S5 = "" #@param {type:"string"}

print("✅ Respuestas de la Semana 5 guardadas en memoria con éxito.")

# %%
r_vola_s5 = globals().get('Respuesta_Volatil_S5', '')
r_hash_s5 = globals().get('Respuesta_Hash_S5', '')
r_cust_s5 = globals().get('Respuesta_Custodia_S5', '')

print("="*80)
print("📌 RESUMEN DE RESPUESTAS REGISTRADAS - SEMANA 5")
print("="*80)
print(f" 1. Evidencia Volátil/No Volátil: {r_vola_s5.strip() if r_vola_s5.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 2. Hashing e Integridad:         {r_hash_s5.strip() if r_hash_s5.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 3. Cadena de Custodia:           {r_cust_s5.strip() if r_cust_s5.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print("="*80)
