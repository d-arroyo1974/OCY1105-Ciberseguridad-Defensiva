# %% [markdown]
# <a href="https://colab.research.google.com/github/d-arroyo1974/OCY1105-Ciberseguridad-Defensiva/blob/main/Act_S2_Las_tecnolog%C3%ADas%2C_procesos_y_roles_de_un_SOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛡️ GUÍA 1.2.2: Las Tecnologías, Procesos y Roles de un SOC
# **Asignatura:** Introducción a la Ciberseguridad (CSY3122) | **Experiencia:** EA1 (IL 1.1)
# **Modalidad:** Online Sincrónica | Trabajo en Equipos (2 estudiantes)
# **Integrantes:** _______________________________________
#
# ---
# ### 📌 Instrucciones para el laboratorio:
# 1. Ve al menú superior: `Archivo` > `Guardar una copia en Drive`.
# 2. Ejecuta la **Celda 1** para cargar el simulador interactivo del **Flujo de Escalamiento del SOC**.
# 3. Mueve el deslizador para recorrer las etapas desde la *Recepción de la Alerta* hasta la *Resolución y Mejoras*.
# 4. Completa los campos de respuesta en las Celdas 2, 3 y 4.
# 5. **CRÍTICO:** Recuerda hacer clic en el botón **Play (▶️)** de CADA celda de formulario tras responder para guardar tus datos en memoria antes de ejecutar el consolidado final.

# %%
# ==============================================================================
# CELDA 1: Simulador de Flujo Operativo y Matriz Tecnológica del SOC
# ==============================================================================
import pandas as pd
from ipywidgets import interact, widgets

def flujo_soc_interactivo(paso):
    etapas = {
        1: {
            "Fase": "1. Recepción y Registro de Alerta",
            "Rol": "Analista SOC Nivel 1 (N1)",
            "Accion": "Recepción de alerta inusual desde SIEM/EDR y creación del ticket de incidente.",
            "Tecnologias": "SIEM, EDR, Sistema de Gestión de Tickets",
            "Estado": "🟡 Triaje Inicial"
        },
        2: {
            "Fase": "2. Triaje e Investigación Inicial (N1 -> N2)",
            "Rol": "Analista SOC Nivel 1 (N1) / Nivel 2 (N2)",
            "Accion": "Evaluación de gravedad. Si supera capacidad de N1, se escala formalmente a N2.",
            "Tecnologias": "Sistema de Tickets, SIEM",
            "Estado": "🟠 Escalado a N2"
        },
        3: {
            "Fase": "3. Investigación Detallada y Forense (N2 -> N3)",
            "Rol": "Analista SOC Nivel 2 (N2) / Nivel 3 (N3)",
            "Accion": "Análisis causa-raíz y mitigación. Si es un incidente complejo/desconocido, escala a N3.",
            "Tecnologias": "Herramientas Forenses (Memory/Disk Analysis)",
            "Estado": "🔴 Escalado a N3"
        },
        4: {
            "Fase": "4. Investigación Avanzada e Ingeniería Inversa",
            "Rol": "Analista SOC Nivel 3 (N3)",
            "Accion": "Análisis avanzado de malware, desensamblado/reversing e identificación de IoCs.",
            "Tecnologias": "Sandbox, Desensambladores (Reversing), Malware Analysis Tools",
            "Estado": "🔬 Análisis Técnico Profundo"
        },
        5: {
            "Fase": "5. Resolución, Documentación y Lecciones Aprendidas",
            "Rol": "Todos los Analistas (N1, N2, N3) y Gerente del SOC",
            "Accion": "Cierre de ticket, reporte ejecutivo, actualización de reglas en SIEM e implementación de mejoras.",
            "Tecnologias": "Sistema de Tickets, Plataforma de Documentación / KB",
            "Estado": "🟢 Cierre y Lecciones Aprendidas"
        }
    }

    info = etapas[paso]
    print("="*80)
    print(f"📌 ETAPA DEL SOC: {info['Fase']}")
    print("="*80)
    print(f"👤 Rol Principal:      {info['Rol']}")
    print(f"⚙️ Acción Clave:        {info['Accion']}")
    print(f"🛠️ Tecnologías:        {info['Tecnologias']}")
    print(f"🏷️ Estado del Ticket:   {info['Estado']}")
    print("="*80 + "\n")

print("✅ Simulador de Flujo del SOC cargado correctamente. Mueve el deslizador:")
interact(
    flujo_soc_interactivo,
    paso=widgets.IntSlider(min=1, max=5, step=1, value=1, description="Paso del SOC:")
);
# Out:
# ✅ Simulador de Flujo del SOC cargado correctamente. Mueve el deslizador:
# interactive(children=(IntSlider(value=1, description='Paso del SOC:', max=5, min=1), Output()), _dom_classes=(…

# %%
#@title 📝 PARTE 1: Matriz de Roles y Tareas en el SOC

#@markdown ---
#@markdown **1. Tareas del Analista N1 (Triaje y Monitoreo):**
#@markdown Describe brevemente las acciones del N1 desde la alerta hasta el escalamiento.
Respuesta_Rol_N1 = "DEAM" #@param {type:"string"}

#@markdown **2. Tareas del Analista N2 (Investigación Detallada):**
#@markdown Describe las acciones del N2 para encontrar la causa raíz y mitigar el incidente.
Respuesta_Rol_N2 = "DEAM" #@param {type:"string"}

#@markdown **3. Tareas del Analista N3 (Investigación Avanzada):**
#@markdown Describe el rol del N3 frente a incidentes complejos o malware no identificado.
Respuesta_Rol_N3 = "DEAM" #@param {type:"string"}

#@markdown **4. Rol del Gerente del SOC:**
#@markdown ¿Qué función cumple el Gerente del SOC durante y después de la resolución del incidente?
Respuesta_Rol_Gerente = "DEAM" #@param {type:"string"}

print("✅ Parte 1 registrada en memoria. (Asegúrate de haber presionado ▶️ en esta celda).")
# Out:
# ✅ Parte 1 registrada en memoria. (Asegúrate de haber presionado ▶️ en esta celda).

# %%
#@title 📝 PARTE 2: Tecnologías y Soluciones Comerciales del Mercado

#@markdown ---
#@markdown **1. Plataformas SIEM y EDR (Investiga 2 marcas comerciales reconocidas):**
#@markdown Ej: Splunk, Microsoft Sentinel, CrowdStrike, SentinelOne, IBM QRadar, etc.
Respuesta_Marcas_SIEM_EDR = "DEAM" #@param {type:"string"}

#@markdown **2. Sistemas de Gestión de Tickets / SOAR:**
#@markdown Indiquen al menos 1 o 2 herramientas para gestión de tickets e incidentes del SOC (ej: ServiceNow, Jira Service Desk, Cortex XSOAR).
Respuesta_Marcas_Tickets = "DEAM" #@param {type:"string"}

#@markdown **3. Herramientas de Análisis Forense e Ingeniería Inversa (Reversing):**
#@markdown Menciona herramientas usadas para análisis forense o análisis de malware (ej: FTK Imager, Volatility, Ghidra, Wireshark, IDA Pro).
Respuesta_Marcas_Forense = "DEAM" #@param {type:"string"}

print("✅ Parte 2 registrada en memoria. (Asegúrate de haber presionado ▶️ en esta celda).")
# Out:
# ✅ Parte 2 registrada en memoria. (Asegúrate de haber presionado ▶️ en esta celda).

# %%
# ==============================================================================
# CELDA FINAL: Consolidado de Respuestas para la Clase Sincrónica
# ==============================================================================
print("="*85)
print("📌 RESUMEN DE RESPUESTAS: GUÍA 1.2.2 - TECNOLOGÍAS, PROCESOS Y ROLES DE UN SOC")
print("="*85)

print("\n👥 PARTE 1: ROLES Y ACCIONES EN EL SOC")
print(f" 1. Analista N1:      {Respuesta_Rol_N1 if Respuesta_Rol_N1.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 1]'}")
print(f" 2. Analista N2:      {Respuesta_Rol_N2 if Respuesta_Rol_N2.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 1]'}")
print(f" 3. Analista N3:      {Respuesta_Rol_N3 if Respuesta_Rol_N3.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 1]'}")
print(f" 4. Gerente de SOC:   {Respuesta_Rol_Gerente if Respuesta_Rol_Gerente.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 1]'}")

print("\n🛠️ PARTE 2: INVESTIGACIÓN DE TECNOLOGÍAS Y MARCAS")
print(f" 1. SIEM / EDR:       {Respuesta_Marcas_SIEM_EDR if Respuesta_Marcas_SIEM_EDR.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 2]'}")
print(f" 2. Tickets / SOAR:   {Respuesta_Marcas_Tickets if Respuesta_Marcas_Tickets.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 2]'}")
print(f" 3. Forense / Malware:{Respuesta_Marcas_Forense if Respuesta_Marcas_Forense.strip() else '⚠️ [Sin respuesta - Presiona Play (▶️) en la celda de la Parte 2]'}")
print("="*85)
# Out:
# ...
# 📌 RESUMEN DE RESPUESTAS: GUÍA 1.2.2 - TECNOLOGÍAS, PROCESOS Y ROLES DE UN SOC
# ...
#
# 👥 PARTE 1: ROLES Y ACCIONES EN EL SOC
#  1. Analista N1:      DEAM
#  2. Analista N2:      DEAM
#  3. Analista N3:      DEAM
#  4. Gerente de SOC:   DEAM
#
# 🛠️ PARTE 2: INVESTIGACIÓN DE TECNOLOGÍAS Y MARCAS
#  1. SIEM / EDR:       DEAM
#  2. Tickets / SOAR:   DEAM
#  3. Forense / Malware:DEAM
# ...
