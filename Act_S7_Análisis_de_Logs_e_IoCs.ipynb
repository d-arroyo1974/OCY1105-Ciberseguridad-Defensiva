# %% [markdown]
# <a href="https://colab.research.google.com/github/d-arroyo1974/OCY1105-Ciberseguridad-Defensiva/blob/main/Act_S7_An%C3%A1lisis_de_Logs_e_IoCs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 📝 FORMULARIO DE RESPUESTAS: Semana 7 - Logs e Indicadores de Compromiso
#@markdown ---
#@markdown **1. Tipo de evento/log sospechoso identificado (Ej: Event ID 4625, HTTP 403/500):**
Respuesta_Log_S7 = "" #@param {type:"string"}

#@markdown **2. Indicadores de Compromiso (IoCs) detectados (IP, Hash, Dominio):**
Respuesta_IoC_S7 = "" #@param {type:"string"}

#@markdown **3. Diagnóstico de la amenaza detectada:**
Respuesta_Diagnostico_S7 = "" #@param {type:"string"}

print("✅ Respuestas de la Semana 7 guardadas en memoria con éxito.")

# %%
r_logs_s7 = globals().get('Respuesta_Log_S7', '')
r_iocs_s7 = globals().get('Respuesta_IoC_S7', '')
r_diag_s7 = globals().get('Respuesta_Diagnostico_S7', '')

print("="*80)
print("📌 RESUMEN DE RESPUESTAS REGISTRADAS - SEMANA 7")
print("="*80)
print(f" 1. Registros/Logs Clave: {r_logs_s7.strip() if r_logs_s7.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 2. IoCs Identificados:   {r_iocs_s7.strip() if r_iocs_s7.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 3. Diagnóstico Técnico:   {r_diag_s7.strip() if r_diag_s7.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print("="*80)
