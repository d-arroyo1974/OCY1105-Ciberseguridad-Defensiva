# %% [markdown]
# <a href="https://colab.research.google.com/github/d-arroyo1974/OCY1105-Ciberseguridad-Defensiva/blob/main/Act_S8_Threat_Hunting_y_Detecci%C3%B3n_Proactiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏹 Laboratorio S8: Threat Hunting Proactivo y Reglas de Detección en SIEM/EDR
# **Asignatura:** Ciberseguridad Defensiva (OCY1105 / CSY3122)
# **Unidad:** EA3 - Monitoreo y Detección Proactiva de Amenazas
#
# ---
#
# ### 📋 Contexto del Caso Práctico
# En lugar de esperar a que salte una alerta del antivirus, la organización requiere una estrategia proactiva. Tu misión como Threat Hunter es formular una hipótesis de amenaza (ej: abuso de herramientas legítimas del sistema como `certutil` o `bitsadmin`) y crear una regla de detección automática en el SIEM/EDR para frenar al atacante a tiempo.
#
# ### 🎯 Objetivos de la Sesión
# 1. Plantear una hipótesis de caza de amenazas basada en el framework MITRE ATT&CK.
# 2. Estructurar una regla de detección básica (Lógica Sigma / YARA / Query SIEM).
# 3. Definir una respuesta automatizada para aislar el host ante coincidencias de la regla.
#
# ---
# ### 🛠️ Instrucciones
# Plantea tu regla y estrategia de hunting en el formulario interactivo y presiona **Play (▶️)** para guardar tus respuestas en la consolidación final.

# %%
#@title 📝 FORMULARIO DE RESPUESTAS: Semana 8 - Threat Hunting y Reglas SIEM/EDR
#@markdown ---
#@markdown **1. Hipótesis de Threat Hunting planteada:**
Respuesta_Hipotesis_S8 = "" #@param {type:"string"}

#@markdown **2. Regla de detección diseñada (Ej: Regla Sigma/YARA/SIEM):**
Respuesta_Regla_S8 = "" #@param {type:"string"}

#@markdown **3. Acción automatizada propuesta ante detección:**
Respuesta_Accion_S8 = "" #@param {type:"string"}

print("✅ Respuestas de la Semana 8 guardadas en memoria con éxito.")

# %%
r_hipo_s8 = globals().get('Respuesta_Hipotesis_S8', '')
r_regl_s8 = globals().get('Respuesta_Regla_S8', '')
r_acci_s8 = globals().get('Respuesta_Accion_S8', '')

print("="*80)
print("📌 RESUMEN DE RESPUESTAS REGISTRADAS - SEMANA 8")
print("="*80)
print(f" 1. Hipótesis Hunting: {r_hipo_s8.strip() if r_hipo_s8.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 2. Regla Detección:   {r_regl_s8.strip() if r_regl_s8.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 3. Respuesta Automática: {r_acci_s8.strip() if r_acci_s8.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print("="*80)
