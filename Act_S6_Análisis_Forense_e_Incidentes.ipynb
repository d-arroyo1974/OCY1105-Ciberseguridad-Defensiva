# %% [markdown]
# <a href="https://colab.research.google.com/github/d-arroyo1974/OCY1105-Ciberseguridad-Defensiva/blob/main/Act_S6_An%C3%A1lisis_Forense_e_Incidentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 📝 FORMULARIO DE RESPUESTAS: Semana 6 - Análisis Forense y Erradicación
#@markdown ---
#@markdown **1. Artefacto o Log de sistema clave analizado:**
Respuesta_Artefacto_S6 = "" #@param {type:"string"}

#@markdown **2. Medida de Contención inmediata del sistema afectado:**
Respuesta_Contencion_S6 = "" #@param {type:"string"}

#@markdown **3. Estrategia de Erradicación y Recuperación:**
Respuesta_Erradicacion_S6 = "" #@param {type:"string"}

print("✅ Respuestas de la Semana 6 guardadas en memoria con éxito.")

# %%
r_arte_s6 = globals().get('Respuesta_Artefacto_S6', '')
r_cont_s6 = globals().get('Respuesta_Contencion_S6', '')
r_erra_s6 = globals().get('Respuesta_Erradicacion_S6', '')

print("="*80)
print("📌 RESUMEN DE RESPUESTAS REGISTRADAS - SEMANA 6")
print("="*80)
print(f" 1. Artefacto Analizado:  {r_arte_s6.strip() if r_arte_s6.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 2. Medida de Contención: {r_cont_s6.strip() if r_cont_s6.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print(f" 3. Erradicación:         {r_erra_s6.strip() if r_erra_s6.strip() else '⚠️ [Sin respuesta - Presiona Play ▶️ arriba]'}")
print("="*80)
